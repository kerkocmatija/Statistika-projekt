# %% [markdown]
# # Seminarska naloga pri predmetu Statistika 2018/19

# %% [markdown]
# Prebivalci Kibergarda

# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt

pd.options.display.max_rows = 14
pd.options.display.max_columns = 10

# %%
Podatki_Kibergrad = pd.read_csv('STATISTIKA_PROJEKT\Kibergrad.csv', encoding='latin1')
Podatki_Kibergrad
# Out:
#        TIP  CLANOV  OTROK  DOHODEK  CETRT  IZOBRAZBA
# 0        1       2      0    43450      1         39
# 1        1       2      0    79000      1         40
# 2        1       2      0    51306      1         39
# 3        1       4      2    24850      1         41
# 4        1       4      2    65145      1         43
# 5        3       3      2    23015      1         40
# 6        3       2      1    26000      1         40
# ...    ...     ...    ...      ...    ...        ...
# 43879    1       4      2    48936      4         43
# 43880    1       5      2    47264      4         41
# 43881    1       5      3    30800      4         36
# 43882    1       2      0    16684      4         34
# 43883    1       2      0    12000      4         39
# 43884    1       2      0    50022      4         34
# 43885    1       9      7    21082      4         39
#
# [43886 rows x 6 columns]

# %% [markdown]
# Izberemo enostavni slučajni vzorec 500 družin.

# %%
Vzorec1 = Podatki_Kibergrad.sample(n=500) #TEGA NE POŽENEMO VEČ, KER ŽELIMO, DA VZOREC OSTANE ENAK!!!

# %%
Vzorec1
# Out:
#        TIP  CLANOV  OTROK  DOHODEK  CETRT  IZOBRAZBA
# 41051    1       2      0    62673      4         44
# 43035    1       4      1    55562      4         39
# 9378     3       3      2    48999      1         39
# 19517    1       2      0    52840      2         43
# 14135    1       3      0    39147      2         45
# 35211    3       2      1    13000      4         40
# 10490    1       4      0    53435      2         43
# ...    ...     ...    ...      ...    ...        ...
# 16550    1       2      0     9746      2         39
# 26358    1       2      0    10123      3         32
# 41902    1       4      2    15000      4         45
# 8803     1       2      0    26396      1         39
# 21552    1       5      1    33000      3         35
# 26174    1       4      2    64295      3         40
# 16483    3       3      0    65936      2         39
#
# [500 rows x 6 columns]

# %%
Skatla_Z_Brki = Vzorec1.boxplot(column = 'DOHODEK', by = 'TIP');
plt.ylabel('DOHODEK')
plt.title('DOHODEK GLEDE NA TIP DRUŽINE')
plt.suptitle('')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Poglejmo še nekoliko prilagojen pogled, le za škatle.

# %%
Skatla_Z_Brki = Vzorec1.boxplot(column = 'DOHODEK', by = 'TIP', showfliers=False);
plt.title('DOHODEK GLEDE NA TIP DRUŽINE')
plt.ylabel('DOHODEK')
# Skatla_Z_Brki.set_ylim(-30000,130000)
plt.suptitle('')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Vzemimo sedaj še dodatne štiri slučajne vzorce:

# %%
Vzorec2 = Podatki_Kibergrad.sample(n=500) #TEGA NE POŽENEMO VEČ, KER ŽELIMO, DA VZOREC OSTANE ENAK!!!
Vzorec3 = Podatki_Kibergrad.sample(n=500) #TEGA NE POŽENEMO VEČ, KER ŽELIMO, DA VZOREC OSTANE ENAK!!!
Vzorec4 = Podatki_Kibergrad.sample(n=500) #TEGA NE POŽENEMO VEČ, KER ŽELIMO, DA VZOREC OSTANE ENAK!!!
Vzorec5 = Podatki_Kibergrad.sample(n=500) #TEGA NE POŽENEMO VEČ, KER ŽELIMO, DA VZOREC OSTANE ENAK!!!

# %%
Vzorec2
# Out:
#        TIP  CLANOV  OTROK  DOHODEK  CETRT  IZOBRAZBA
# 40119    1       6      4    44200      4         37
# 4562     3       2      1    15600      1         37
# 20972    1       3      0    29478      3         40
# 3069     1       2      0   137225      1         44
# 42452    1       2      0     9055      4         33
# 14421    1       3      0    58430      2         34
# 20652    1       2      0    22870      3         39
# ...    ...     ...    ...      ...    ...        ...
# 12813    1       4      2   104200      2         44
# 41806    1       2      0    14672      4         32
# 32197    3       2      1     8150      3         39
# 14240    1       5      1    50048      2         40
# 13280    1       3      0    99485      2         39
# 21162    1       3      0    91600      3         39
# 17610    1       2      0    13933      2         39
#
# [500 rows x 6 columns]

# %%
Vzorec3
# Out:
#        TIP  CLANOV  OTROK  DOHODEK  CETRT  IZOBRAZBA
# 33796    3       2      0     9797      3         33
# 24318    1       2      0    29969      3         40
# 5264     1       3      1    49064      1         46
# 5162     1       2      0    33348      1         39
# 31582    1       2      0    21120      3         39
# 9519     1       5      3    35700      1         41
# 18567    1       2      0    19705      2         34
# ...    ...     ...    ...      ...    ...        ...
# 34986    3       4      3     4500      4         39
# 21261    1       5      3    22841      3         39
# 21677    2       4      0    71440      3         44
# 10654    1       2      0    35416      2         37
# 17092    1       3      0    10543      2         34
# 8151     1       4      0   132071      1         43
# 21793    1       5      3   121399      3         45
#
# [500 rows x 6 columns]

# %%
Vzorec4
# Out:
#        TIP  CLANOV  OTROK  DOHODEK  CETRT  IZOBRAZBA
# 39336    3       5      1    43924      4         39
# 10011    1       2      0     7507      1         39
# 27594    1       2      0    20159      3         35
# 29166    1       5      3    39726      3         41
# 23608    3       3      2    18813      3         39
# 31462    1       2      0    40010      3         40
# 2993     1       2      0    55440      1         43
# ...    ...     ...    ...      ...    ...        ...
# 37460    3       2      0    13453      4         42
# 39564    1       2      0     9500      4         33
# 40484    1       2      0    17670      4         35
# 30400    1       4      2    31200      3         40
# 31898    1       2      0    58350      3         43
# 42037    1       7      5    16000      4         37
# 28690    1       2      0    15148      3         34
#
# [500 rows x 6 columns]

# %%
Vzorec5
# Out:
#        TIP  CLANOV  OTROK  DOHODEK  CETRT  IZOBRAZBA
# 17312    1       5      3    42397      2         39
# 15220    3       4      3     5588      2         37
# 42358    1       3      0   147804      4         42
# 69       1       2      0    54177      1         44
# 35970    3       3      2    21960      4         34
# 4716     1       4      2    38900      1         40
# 3750     1       3      0    63060      1         40
# ...    ...     ...    ...      ...    ...        ...
# 18581    1       3      1    56580      2         43
# 5103     3       2      0    15000      1         43
# 33507    1       2      0    56508      3         43
# 74       3       2      0    25541      1         39
# 30003    3       2      0    18860      3         40
# 19877    1       2      0    36250      2         40
# 22209    1       4      2    11400      3         40
#
# [500 rows x 6 columns]

# %% [markdown]
# Tukaj sedaj najprej izberemo vzorce, ter se nato omejimo le na družine Tipa 1.

# %%
Vzorec1_Popravljen = Vzorec1[(Vzorec1.TIP == 1)]
Vzorec2_Popravljen = Vzorec2[(Vzorec2.TIP == 1)]
Vzorec3_Popravljen = Vzorec1[(Vzorec1.TIP == 1)]
Vzorec4_Popravljen = Vzorec1[(Vzorec1.TIP == 1)]
Vzorec5_Popravljen = Vzorec1[(Vzorec1.TIP == 1)]
Vzorec1_Popravljen
# Out:
#        TIP  CLANOV  OTROK  DOHODEK  CETRT  IZOBRAZBA
# 41051    1       2      0    62673      4         44
# 43035    1       4      1    55562      4         39
# 19517    1       2      0    52840      2         43
# 14135    1       3      0    39147      2         45
# 10490    1       4      0    53435      2         43
# 33428    1       2      0    40091      3         44
# 15297    1       2      0    40000      2         44
# ...    ...     ...    ...      ...    ...        ...
# 36995    1       6      3    19267      4         33
# 16550    1       2      0     9746      2         39
# 26358    1       2      0    10123      3         32
# 41902    1       4      2    15000      4         45
# 8803     1       2      0    26396      1         39
# 21552    1       5      1    33000      3         35
# 26174    1       4      2    64295      3         40
#
# [382 rows x 6 columns]

# %%
Novi_Podatki = [Vzorec1_Popravljen['DOHODEK'], Vzorec2_Popravljen['DOHODEK'],
                Vzorec3_Popravljen['DOHODEK'], Vzorec4_Popravljen['DOHODEK'], Vzorec5_Popravljen['DOHODEK']]

# %%
fig = plt.figure()
axes = fig.add_subplot(111)
Skupinska_Skatla = axes.boxplot(Novi_Podatki)
plt.title('DOHODEK DRUŽIN TIPA 1 V PETIH SLUČAJNIH VZORCIH')
plt.suptitle('')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
medianprops = dict(color='k')
axes = fig.add_subplot(111)
Skupinska_Skatla = axes.boxplot(Novi_Podatki, showfliers=False)
plt.title('DOHODEK DRUŽIN TIPA 1 V PETIH SLUČAJNIH VZORCIH')
plt.suptitle('')
# Out:
# <img src="data:image/png;base64,..." width="640">
